# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Malindu Lawrence**
#
# Student

# %% [markdown]
# *I am interested in data science because i love data science*

# %% [markdown]
# ### Add "5"+"5"

# %%
print(5+5)
# Out:
# 10

# %% [markdown]
# - one
# - Two
# - Three
# ![DMZFslWXkAAyg5Q.jpg](attachment:DMZFslWXkAAyg5Q.jpg)
# * four
# 1. one

# %% [markdown]
# # Peer-graded Assignment

# %% [markdown]
# this is my peer graded assignment

# %% [markdown]
# Data science languages
# - Python
# - R
# - SQL
# - Java
# - Julia

# %% [markdown]
# Data science libraries
# - NumPy
# - Pandas
# - Matplotlib

# %% [markdown]
# |Data Science tools|
# |------------|
# |Jupyter Notebook|
# |Tableau|
# |Apache Spark|

# %% [markdown]
# 7-1=6

# %%
print(5*2+8)
# Out:
# 18

# %%
time=int(input('minuets :'))
print(time/3600)
# Out:
# minuets :72000
# 20.0

# %% [markdown]
# Objetives

# %% [markdown]
# **Malindu Lawrence**
